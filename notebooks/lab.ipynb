# %%
from vnstock import register_user

register_user(api_key="vnstock_bd5b1e073dc9649ab3049797c08327a7")
# Out:
# Running cells with 'ourportfolios (3.13.11) (Python 3.13.11)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/dank/Documents/Codebases/ourportfolios-net/ourportfolios/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
